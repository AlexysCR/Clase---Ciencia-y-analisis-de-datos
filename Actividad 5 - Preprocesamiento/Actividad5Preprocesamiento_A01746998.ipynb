# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Alexys Martín Coate Reyes
# *   MATRÍCULA: A017446998

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import os
#DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
#os.chdir(DIR)
print(os.getcwd())
# Out:
# /workspaces/actividades-AlexysCR/Actividad 5 - Preprocesamiento

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
response_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %% [markdown]
# #### **Respuesta**
#
# De acuerdo al análisis de "info()" podemos determinar que tenemos las siguientes variables:
#
# * **Numéricas**
#     * fLoat64: 134
#     * int64 : 5
# * **Texto**
#     * object: 11

# %%
# Resumen de estadísticas descriptivas para elementos numéricos
response_df.describe(include=["number"])
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# ...

# %%
# Resumen de estadísticas descriptivas para elementos de tipo object
response_df.describe(include=["object"])
# Out:
#               Smoking         Alcohol          Punctuality      Lying  \
# count            1002            1005                 1008       1008
# unique              4               3                    3          4
# top     tried smoking  social drinker  i am always on time  sometimes
# freq              430             659                  399        549
#
#          Internet usage  Gender Left - right handed         Education  \
# count              1010    1004                1007              1009
# unique                4       2                   2                 6
# top     few hours a day  female        right handed  secondary school
# freq                744     593                 906               621
#
#        Only child Village - town House - block of flats
# count        1008           1006                   1006
# unique          2              2                      2
# top            no           city         block of flats
# ...

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.

# %%
print(len(response_df["Weight"]))
# Out:
# 1010

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))

# Graficando histograma
ax[0].hist(response_df["Weight"],bins=30,edgecolor="black")  
ax[0].set_title("Histograma")

# Graficando grafica de barras
ax[1].bar(range(len(response_df)),response_df["Weight"])
ax[1].set_title("Grafico de Barras")

fig.show()

# %% [markdown]
# #### **Respuesta**
#
# El mejor gráfico para elegir sería el histograma por las siguientes razones:
#
# * Existe una gran cantidad de datos. 990 no nulos para la variable de weight, por lo que no pueden mostrarse tal cantidad de datos en la gráfica. Es necesario clasificarlos.
# * Con el histograma podemos graficar la frecuencia de los valores y así minimizar el tamaño del grafico, quedando  en el eje "x" el peso (min: 41kg, max: 165kg) y en el eje "y" la frecuenca de los valores. Esto permitirá visualizar mejor la escala de las mediciones.

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.

# %%
# Calculo de asimetría (Skew)
response_df["Weight"].skew()
# Out:
# np.float64(1.2237251927527477)

# %% [markdown]
# #### **Respuesta**
#
# Cómo el valor de skewness es de: 1.224, significa que tenemos una asimetría positiva o sesgo a la derecha, por lo que significa que la cola del histograma está en la parte de la derecha. Este resultado, podemos cotejarlo con la histograma resultante de arriba.

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
# Calculo de valores faltantes
valoresTotales = len(response_df["Weight"])
valoresConInfo = len(response_df["Weight"].dropna())
valoresFaltantes = valoresTotales - valoresConInfo
print("# Filas:", valoresTotales)
print("# Filas con información:", valoresConInfo)
print("# Filas sin información:", valoresFaltantes)

# Porcentaje de valores faltantes
porcentaje = response_df["Weight"].isna().mean() * 100
print("Porcentaje de valores faltantes:", porcentaje,"%")
# Out:
# # Filas: 1010
# # Filas con información: 990
# # Filas sin información: 20
# Porcentaje de valores faltantes: 1.9801980198019802 %

# %% [markdown]
# #### **Respuesta**
#
# * Valores faltantes de la variable "Weight": 20
# * Porcentaje de valores faltantes: 1.98%

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas. NO olvides incluir las conclusiones del análisis con los resultados obtenidos.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
numerical_attributes = ["Age","Number of siblings"]

BM_MV = response_df["Weight"].isna()
for att in numerical_attributes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Numerical(response_df, att, BM_MV)
    print('- - - - - - - - - - - - ----- - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Age:
# p-value of t-test: 0.7258243979822129
# - - - - - - - - - - - - ----- - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Number of siblings:
# p-value of t-test: 0.8255092107556896
# - - - - - - - - - - - - ----- - - - - - - - - - - -

# %%
categorical_attibutes = ["Gender","Education"]

BM_MV = response_df["Weight"].isna()
for att in categorical_attibutes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Categorical(response_df,att,BM_MV)
    print('- - - - - - - - - - - - divider - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Gender:
# p-value of Chi_squared test: 0.5472167199163878
# - - - - - - - - - - - - divider - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Education:
# p-value of Chi_squared test: 0.8424822989541867
# - - - - - - - - - - - - divider - - - - - - - - - - -

# %% [markdown]
# #### **Respuesta**
#
# De acuerdo a los datos, podríamos intuir que el BMI va a cambiar para la edad y el genero de la gente. Al ver las gráficas podemos ver que tanto la gráfica de valores faltantes como la otra, son en general muy similares y eso demuestra una buena selección de muestras.
#
# Particularmente, la gráfica de edad fue la que mostró más cambios, llegando reducirse los bigotes del boxplot. Esto significa una mayor centralización de los valores.

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %%
# Calculando la moda
moda = response_df["Weight"].mode().to_list()
print("Moda:",str(moda))

# OBteniendo la media y la mediana
stats = response_df["Weight"].describe()
display(stats.to_frame())
media = stats["mean"]
mediana = stats["50%"]
# Out:
# Moda: [60.0]
#            Weight
# count  990.000000
# mean    66.405051
# std     13.839561
# min     41.000000
# 25%     55.000000
# 50%     64.000000
# 75%     75.000000
# max    165.000000

# %%
ax = response_df.hist("Weight", bins=30, edgecolor="black")

# Dibujar una línea vertical
for axis in ax.flatten():
    axis.axvline(x=moda, color='orange', linestyle='--', linewidth=2)
    axis.axvline(x=media, color='red', linestyle='--', linewidth=2)
    axis.axvline(x=mediana, color='yellow', linestyle='--', linewidth=2)

# %% [markdown]
# **Respuesta**
#
# Aquí podemos obsevar que las medidas de tendencia central en "Weight" son:
#
# * **Moda:** 60
# * **Mediana:** 64
# * **Media:** 66
#
# Podemos observar que todas las mediciones de peso, son bastante similares. De acuerdo con el histograma y las mediciones del sesgo (skew), podemos observar que tenemos sesgo positivo (cola a la derecha) con un valor de 1.22. Como existe un sego positivo, la media no representa de mejor manera todos los valores, porque no tenemos una distribución normal. En este caso la mejor medida de tendencia, sería la mediana, ya que es la parte media de los datos y se ve menos afectada por los outliers de la cola derecha.

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
# Graficando Boxplot
response_df.boxplot("Weight", vert=False)
# Out:
# <Axes: >

# %%
# Obteniendo final del bigote del boxplot
response_df["Weight"].describe()
IQR = 75-55
endBar = 75 + (1.5*IQR)
print("Fin del bigote:",endBar)

# Obteniendo y almacenando Outliers
outliers_weight = response_df["Weight"][response_df["Weight"] > endBar].sort_values().to_frame()
display(outliers_weight)
print("Num Outliers:",len(outliers_weight))
# Out:
# Fin del bigote: 105.0
#      Weight
# 612   110.0
# 715   111.0
# 796   113.0
# 292   120.0
# 793   120.0
# 973   120.0
# 859   125.0
# 992   150.0
# 885   165.0
# Num Outliers: 9

# %%
# Eliminando Outliers del conjunto original
df_clean_weight = response_df.drop(outliers_weight.index)
display(df_clean_weight)
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# #### **Respuesta**
#
# Existen 9 outliers en la columna "Weight", que son los siguientes:
#
# **Outliers**
#
# | Indice    | Weight |
# |-----|--------|
# | 612 | 110.0  |
# | 715 | 111.0  |
# | 796 | 113.0  |
# | 292 | 120.0  |
# | 793 | 120.0  |
# | 973 | 120.0  |
# | 859 | 125.0  |
# | 992 | 150.0  |
# | 885 | 165.0  |
#
#
# Estos fueron borrados del dataframe orignial con éxito. Ver preuba de impresión del data frame limpio.

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
# Graficando Boxplot
response_df.boxplot("Height", vert=False)
# Out:
# <Axes: >

# %%
# Calculando último valor del bigote
response_df["Height"].describe()
IQR = 180 - 167
endBar = 180 + (1.5*IQR)
print("Final del bigote:",endBar)

# Obteniendo dataframe con outliers
outliers_height = response_df["Height"][response_df["Height"] > endBar].sort_values().to_frame()
display(outliers_height)
print("# Outliers:",len(outliers_height))
# Out:
# Final del bigote: 199.5
#      Height
# 97    200.0
# 220   200.0
# 992   200.0
# 547   203.0
# 799   203.0
# # Outliers: 5

# %%
# Eliminando outliers de una copia del data frame original
df_clean_height = response_df.drop(outliers_height.index)
display(df_clean_height)

print("Original data frame size:",len(response_df))
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# #### **Respuesta**
#
# En la columna "Height" se encontraron 5 outliers, los cuales son:
#
# | Index    | Height |
# |-----|--------|
# | 97  | 200.0  |
# | 220 | 200.0  |
# | 992 | 200.0  |
# | 547 | 203.0  |
# | 799 | 203.0  |
#
# Los outliers fueron eliminados con exito del conjutno original!

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
# Calculando el BMI y guardando el resultado en una columna del data frame original
response_df["BMI"] = response_df["Weight"]/(response_df["Height"]/100)**2
display(response_df["BMI"].to_frame())
# Out:
#             BMI
# 0     18.066167
# 1     21.829952
# 2     21.629649
# 3     19.943213
# 4     20.415225
# ...         ...
# 1005  21.192742
# 1006  23.888441
# 1007  25.059307
# 1008  19.379197
# 1009  21.037253
#
# [1010 rows x 1 columns]

# %%
# Verificando presencia de "Outliers" con un boxplot
response_df.boxplot("BMI", vert=False)
# Out:
# <Axes: >

# %%
# Calculo de outliers
Q1 = response_df["BMI"].quantile(0.25)
Q3 = response_df["BMI"].quantile(0.75)
IQR = Q3 - Q1
bigote_superior = Q3 + (1.5*IQR)
print("Bigote superior:",bigote_superior)

# Creando dataframe de outliers
outliers_bmi = response_df["BMI"][response_df["BMI"] > bigote_superior].to_frame()
display(outliers_bmi)
print("# Outliers:", len(outliers_bmi))
# Out:
# Bigote superior: 29.92108000293946
#             BMI
# 42    31.141869
# 151   30.864198
# 156   30.961729
# 292   35.444234
# 357   29.961612
# 401   31.141869
# 612   37.182261
# 636   31.804658
# 676  143.080125
# 715   33.145212
# 793   35.062089
# 796   31.634053
# 859   34.626039
# 973   39.183673
# 992   37.500000
# # Outliers: 15

# %% [markdown]
# #### **Respuesta**
#
# Si, hay 15 pacientes atípicos con un índice mayor a 29.92 BMI que serían los siguientes:
#
# |  Indice   | BMI        |
# |-----|------------|
# | 42  | 31.141869  |
# | 151 | 30.864198  |
# | 156 | 30.961729  |
# | 292 | 35.444234  |
# | 357 | 29.961612  |
# | 401 | 31.141869  |
# | 612 | 37.182261  |
# | 636 | 31.804658  |
# | 676 | 143.080125 |
# | 715 | 33.145212  |
# | 793 | 35.062089  |
# | 796 | 31.634053  |
# | 859 | 34.626039  |
# | 973 | 39.183673  |
# | 992 | 37.500000  |

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.

# %%
# Cantidad de variables categóricas
cat_df = response_df.select_dtypes(exclude=["number"])
cat_vars = cat_df.columns.to_list()

# Imprimiendo variables categóricas
for cat in cat_vars:
    print(cat)
# Out:
# Smoking
# Alcohol
# Punctuality
# Lying
# Internet usage
# Gender
# Left - right handed
# Education
# Only child
# Village - town
# House - block of flats

# %%
# Boxplot para cada variable categórica en relación al BMI
for cat in cat_vars:
    response_df.boxplot(column="BMI", by=cat, vert=False)

# %% [markdown]
# #### **Respuesta**
#
# Al observar los boxplot detenidamente, se encontraron las siguientes observaciones/curiosidades:
#
# **Gráfica "Internet Usage" vs "BMI"**
#
# Existe una disminución ligera en BMI, mientras se usa menos el internet. Las personas que tenian el estatus de "not at all" tenían los menores BMI de la tabla.
#
# **Gráfica "Gender" vs "BMI"**
#
# Aquí se puede observar que los hombres tienden a tener un mayor BMI, lo que es totalmente normal, por el tipo de cuerpo que tienen.
#
#
# **Gráfica "Eductation" vs "BMI"**
#
# La mayoría de personas que estudian el doctorado, tienen el BMI más alto. Entre las posibles hipotesis, del por que es así, puede ser porque el tiempo que le dedican a sus estudios es mayor, además que la edad de las personas con doctorado es mayor a la edad de los otros rangos educativos, lo que implica un cambio de metabolismo y por ende un aumento en el BMI.
